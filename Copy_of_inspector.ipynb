# %% [markdown]
# <a href="https://colab.research.google.com/github/konjeng/Hello-world/blob/master/Copy_of_inspector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import output

with output.temporary():
  # !pip install --upgrade git+https://github.com/blois/colab_inspector.git
  # !jupyter nbextension install --py inspector

# %%
import inspector
inspector.watch_globals()
# Out:
#     <link rel='stylesheet' href='/nbextensions/google.colab.labs.inspector/inspector.css'>
#     <script src='/nbextensions/google.colab.labs.inspector/inspector.bundle.js'></script>
#     <script>
#       inspectSpec('user_global_ns', {"partial": false, "length": 5, "type": "dict", "spec_type": "dict", "contents": {"output": {"partial": true, "keys": [], "length": 21, "spec_type": "instance", "type": "module", "contents": {}}, "inspector": {"partial": true, "keys": [], "length": 11, "spec_type": "instance", "type": "module", "contents": {}}, "exit": {"partial": true, "keys": [], "length": 22, "spec_type": "instance", "type": "ZMQExitAutocall", "contents": {}}, "get_ipython": {"docs": "Return the currently running IPython instance.", "type": "instancemethod", "spec_type": "function", "arguments": ["self"]}, "quit": {"partial": true, "keys": [], "length": 22, "spec_type": "instance", "type": "ZMQExitAutocall", "contents": {}}}}, false);
#     </script>

# %%
x = 2

# %%
y=5
z=[1,2,3,'4563']

# %%
import numpy as np

# %%
something = "hello"

# %%
import google.colab
